# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Proyecto Final: Introducción a la Ciencia de Datos

# %% [markdown]
# ## Introducción
# La ciencia de datos combina programación, estadísticas y conocimiento de negocio para analizar datos y extraer valor de ellos.
# En este cuaderno se presentarán ejemplos básicos utilizando Jupyterlite.

# %% [markdown]
# ## Lenguajes de la Ciencia de Datos
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Bibliotecas de Ciencia de Datos
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - PyTorch

# %% [markdown]
# ## Herramientas de Ciencia de Datos
#
# | Herramienta       | Descripción                                   |
# |-------------------|-----------------------------------------------|
# | Jupyter Notebook  | Entorno interactivo para análisis de datos     |
# | RStudio           | IDE para análisis estadístico con R            |
# | GitHub            | Control de versiones y colaboración           |
# | Apache Spark      | Procesamiento de grandes volúmenes de datos    |
# | Tableau           | Visualización de datos                        |

# %% [markdown]
# ## Ejemplos de Expresiones Aritméticas
# - Suma: 5 + 3 = 8
# - Resta: 10 - 4 = 6
# - Multiplicación: 7 * 2 = 14
# - División: 20 / 5 = 4

# %%
#Ejercicio 8
a = 5
b = 3
suma = a + b
multiplicacion = a * b

print("Suma:", suma)
print("Multiplicación:", multiplicacion)
# Out:
# Suma: 8
# Multiplicación: 15

# %%
#Ejercicio 9
minutos = 120
horas = minutos / 60
print(f"{minutos} minutos equivalen a {horas} horas")
# Out:
# 120 minutos equivalen a 2.0 horas

# %%
#Ejercicio 10
objetivos = [
    "Aprender fundamentos de ciencia de datos",
    "Conocer herramientas y bibliotecas",
    "Practicar con Jupyterlite",
    "Compartir resultados en GitHub"
]

for i, objetivo in enumerate(objetivos, 1):
    print(f"{i}. {objetivo}")

# %% [markdown]
# **Autor:** Luis Murga

# %% [markdown]
# El cuaderno ha sido compartido en GitHub a través del siguiente enlace público:
# 👉 https://github.com/LMURGAEN/Proyecto-Final-Introducci-n-a-la-Ciencia-de-Datos.git

# %% [markdown]
# ![2-10-2025_184242_labs.cognitiveclass.ai.jpeg](attachment:56311685-71e3-4e73-b293-5ef32464e7e8.jpeg)
